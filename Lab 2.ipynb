# %% [markdown]
# LAB 2:
# In order to keep a better record of the Pet Shop’s business a database containing several tables must be used. The most important tables involve transactions made by the business, notably the Purchases and the Adoptions tables. The attributes included in these tables help the business keep track of which pets have been adopted and how much food has been sold. The Purchases table only really needs to connect to the Food table, while the Adoptions table needs to connect to both the Pets and the Fish tables. Animals and food have a many-to-many relationship, as there are multiple types of pets that can eat multiple types of food. All of the pets and fish need somewhere to live, so each of their tables is connected to either an enclosure or an aquarium, respectively. The habitats are distinguished by a unique ID number, their volume, and their temperature which should each be different depending on the type of animal. It is possible that a habitat does not have any occupants, but typically the relationship between an animal and an enclosure is one-to-one. An optional customer loyalty program also has its own table within the database. This table is not necessarily accessed during every transaction, but can be used to help the business improve its customer relations. The attributes within this table include contact information for each customer, so the pet shop can target specific ads towards its most loyal patrons. Implementing a database would be the best possible idea to organize and access the data necessary to run this pet shop.

# %% [markdown]
# ![image.png](attachment:image.png)
